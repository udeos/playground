# %%
# %matplotlib inline

import numpy as np

from matplotlib import pyplot as plt
from matplotlib import cm
from sklearn import datasets

# %%
X, Y = datasets.make_classification(100, n_features=2, n_redundant=0)
plt.scatter(X[:,0], X[:,1], c=Y, cmap=cm.BuGn)

# %%
class Neuron:
    def __init__(self, n_inputs, threshold, activation_function):
        self.n_inputs = n_inputs
        self.threshold = threshold
        self.activation_function = activation_function
        self.coefs = [1.0] * n_inputs
        self.nu = 0.1
        
    def fit(self, x, y):
        if np.sum(x * self.coefs) >= 0 and y == 0:
# Out:
#   File "<ipython-input-28-e45d4d6abd81>", line 10
#
#     ^
# IndentationError: expected an indented block

# %%
n1 = Neuron(2, None, None)
plt.scatter(X[:,0], X[:,1], c=Y, cmap=cm.BuGn)
t = np.linspace(-5, 5)
plt.plot(t, t * n1.coefs[0] / n1.coefs[1])
